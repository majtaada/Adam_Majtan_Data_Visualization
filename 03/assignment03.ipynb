# %% [markdown]
# # Domácí úkol č. 3 - 📈 Vizualizace ve strojovém učení od A do Z
#
# ## 📚 Data
# Pro tento úkol si studenti **zvolí vhodná data sami**. ☝️ Zvolená data by měla být veřejně dostupná a měla by simulovat nebo odpovídat nějaké reálné situaci (tzn. syntetická/vygenerovaná data neuvažujeme!). Data si vybírejte tak, abyste na nich byli schopni řešit klasifikační nebo regresní úlohu (tedy supervizované učení, přítomnost výstupní proměnné).
#
# **Pro odvážné:** Pokud se cítíte silní v kramflecích, můžete si zvolit i nesupervizovanou úlohu, např. shlukování.
#
# #### Tipy na data a řešení
# V souboru datasets_tips.md můžete najít tipy na různé veřejné weby s datasety.
#
# Inspiraci pro vypracování úkolu najdete v praktických ukázkách k přednáškám č. 8 a 9. Nicméně pouze zkopírovaný kód nebude hodnocen kladně.
#
# ☝️**Pozor!** Zkuste si zvolit trochu nápaditý dataset. Pokud si zvolíte dataset, který je často součástí tutoriálů (např. [Titanic dataset](https://www.tensorflow.org/datasets/catalog/titanic) nebo [Iris dataset](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html#sklearn.datasets.load_iris)), pro zisk plného počtu bodů budete muset zřejmě vynaložit větší úsilí při jeho kreativní a neotřelé prezentaci.
#
# ## Zadání
# > ☝️ Používejte **markdown buňky**! Zdůvodňujte všechny důležité kroky, popisujte vizualizace a co je z nich možné pozorovat. Za nepřehledný domácí úkol nebudou uděleny body.
#
# Za řádné průběžné komentování a vizuální prezentaci postupu a výsledků lze získat až 10 bodů. Notebook odevzdávejte po spuštění (tzn. včetně output buněk) a zkrontrolujte si, že se komentáře korektně zobrazují ('rendered file' na GitLabu ve vašem prohlížeči).
#
# Úkol můžete vypracovávat jako **jednotlivci** nebo **ve skupině maximálně 3 spolužáků**. Postup pro hodnocení skupiny najdete na stránkách předmětu [zde](https://courses.fit.cvut.cz/BI-VIZ/homeworks/index.html#_podrobnosti-k-hodnocen%C3%AD-třet%C3%ADho-úkolu).
#
# ### Pokyny pro vypracování
#
# 🙏 Pokud je to možné, v každém bodě vaší práce **využijte vizualizace** a svá zjištění komentujte.
#
# **📖 Vaše úloha:**
# 1. Popište klasifikační/regresní úlohu, kterou v rámci domácího úkolu budete řešit.
# 2. Uveďte zdroj, odkud čerpáte data. ⛔️ Pozn.: Pokud pracujete s lokálně uloženým datasetem, odevzdejte jej spolu s vyřešeným Jupyter Notebookem prostřednictvím GitLabu. To aby s daty mohl pracovat i vyučující při opravě.
#
# **✨ Dataset:**
# V této části máte za úkol načíst zvolená data a pomocí vizualizace a popisných statistik se s nimi seznámit. Dále je nutné data vhodným způsobem předzpracovat, abyste je mohli použít pro trénování modelu.
# 1. Načtěte si zvolený dataset a importujte potřebné knihovny. Volba knihoven je na vás.
# 2. Představte jednotlivé příznaky pomocí textových popisů.
# 3. Analyzujte dataset pomocí popisných statistik s využitím vhodných vizualizačních metod. Svá zjištění komentujte.
# 4. Vyšetřete chybějící hodnoty (včetně jejich reprezentace) a odlehlá pozorování. Opět využijte vizualizace, pokud je to možné a svá zjištění komentujte.
# 5. Proveďte všechny další úpravy, které jsou podle vás pro práci s vybraným datasetem nezbytné (např. konverze datových typů, odstranění duplicitních údajů, vytvoření nových příznaků, sjednocení reprezentace chybějících dat nebo jejich odstranění apod.). K úpravě datasetu se můžete v průběhu řešení úlohy vracet.
# 6. Připravte dataset tak, abyste na něm mohli natrénovat a vyhodnotit vybraný model (např. data vhodně rozdělte, pokud je to pro váš model a evaluaci nutné, rozdělení komentujte, nebo můžete využít křížovou validaci apod. -> znáte z BI-ML1).
#
# Z této části lze získat celkem 15 bodů.
#
# **⚙️Model:**
# V této části je vaším úkolem natrénovat model, který se pokusí vyřešit vaši úlohu. Zaměřte se především na vizualizaci jednotlivých kroků a výsledků, včetně komentářů. Kvalita modelu jako takového nebude hodnocena.
# 1. Pro svoji úlohu zvolte vhodný klasifikační/regresní model.
# 2. Zvolte si alespoň dva hyperparametry spolu s minimálně pěti hodnotami (zde může být i více, případně méně v závislosti na zvoleném hyperparametru), jejichž nejlepší kombinaci budete během trénování modelu hledat. Zvolené hyperparametry a jejich hodnoty popište.
# 3. Zvolte a popište ztrátovou funkci, pomocí které provedete vyhodnocení úspěšnosti modelu.
# 4. Daný model na datasetu natrénujte. Pokud to lze, model vizualizujte.
# 5. Vhodně vizualizujte a komentujte vliv jednotlivých kombinací hyperparamentrů na úspěšnost modelu. Uveďte nejlepší kombinaci.
# 6. Pokud to lze (!), vizualizujte rozhodovací hranici nejlepšího modelu pro vámi vybrané příznaky. Pokud to nelze, zdůvodněte, případně realizujte jinou viualizaci související s prezentací nejlepšího modelu.
# 7. Vhodně vizualizujte úspěšnost výsledného modelu - využijte alespoň dvě vizualizační metody.
#
# **Pro zájemce:** Pokud byste chtěli, můžete pro řešení úlohy použít modelů více a provést jejich srovnání (včetně ladění hyperparametrů a dalších kroků zmíněných výše).
#
# Z této části lze získat celkem 25 bodů.
#
# ### Bodové hodnocení
# Shrnutí bodů, které můžete nejvýše získat:
# - 10 bodů za průběžné komentáře a vizuální prezentaci postupu a výsledků,
# - 15 bodů za předzpracování a prezentaci dat,
# - 25 bodů za trénování a vyhodnocení modelu:
#
# Celkem lze za domácí úkol č. 3 získat maximálně 50 bodů (každý člen týmu nebo jednotlivec).

# %% [markdown]
# # Predpovedanie futbalových Majstrovstiev sveta v Qatare 2022
# Vybrali sme si datasety, ktoré obsahujú data o medzinárodných futbalových zápasoch a mužstvách. Tieto dáta použijeme na natrénovanie modelu, ktorý bude predpovedať výsledky futbalových zápasov.
# Tento model potom použijeme na predpovedanie výsledkov na Majstrovstvách sveta v Qatare, ktoré sa odohrali v roku 2022.

# %%
import pandas as pd
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.cm as cm

warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.simplefilter(action="ignore", category=DeprecationWarning)
warnings.simplefilter(action="ignore", category=UserWarning)

from sklearn.model_selection import train_test_split

# %%
#makes the plots just the right size
plt.rcParams['figure.figsize'] = (12, 8)

# %% [markdown]
# # Predstavenie datasetov

# %%
results = pd.read_csv('results.csv')
ranking = pd.read_csv('fifa_ranking-2022-12-22.csv')
schedule = pd.read_csv('match-schedule.csv', sep=';')
wc_teams = pd.read_csv('Qatar2022-teams.csv', sep=';')

# %% [markdown]
# ### Dataset ***results***
# Dataset obsahuje výsledky medzinárodných futbalových zápasov od roku 1872.
#
# Dataset obsahuje príznaky:
#  - `date` - dátum zápasu
#  - `home_team` - názov domáceho tímu
#  - `away_team` - názov vonkajšíeho tímu
#  - `home_score` - počet gólov strelených domácim tímom
#  - `away_score` - počet gólov strelených vonkajším tímom
#  - `tournament` - turnaj, v ktorom sa zápas odohral
#  - `city` - mesto, v ktorom sa zápas odohral
#  - `country` - krajina, v ktorej sa zápas odohral
#  - `netral` - TRUE/FALSE hovoriaci o tom, či sa zápas hral na neutrálnej pôde
#
# https://www.kaggle.com/datasets/martj42/international-football-results-from-1872-to-2017

# %% [markdown]
# ### Dataset ***ranking***
# Dataset obsahuje poradie tímov podľa hodnotenia FIFA od roku 1992.
#
# Dataset obsahuje príznaky:
#  - `rank` - poradie tímu
#  - `country_full` - názov tímu
#  - `country_abrv` - skratka tímu
#  - `total_points` - celkové body tímu
#  - `previous_points` - celkové body tímu v poslednom hodnotení
#  - `rank_change` - zmena poradia tímu od posledného hodnotenia
#  - `confederation` - FIFA konfederácie
#  - `rank_date` - dátum hodnotenia
#
# https://www.kaggle.com/datasets/cashncarry/fifaworldranking

# %% [markdown]
# ### Dataset ***schedule***
#
# Dataset obsahuje rozpis zápasov v skupinovej aj vyraďovacej časti majstrovstiev sveta.
#
# Dataset obsahuje príznaky:
#  - `match` - poradové číslo zápasu
#  - `date` - dátum zápasu
#  - `country1` - jedna z krajín hrajúca zápas
#  - `country2` - druhá krajina hrajúca zápas
#  - `phase` - časť turnaja, v ktorej sa zápas hrá
#
# https://www.kaggle.com/datasets/amineteffal/qatar2022worldcupschudule?select=matchs-schudule.csv

# %% [markdown]
# ### Dataset ***wc_teams***
#
# Dataset obsahuje tímy, ktoré sa zúčastnili majstrovstiev sveta v Qatare a skupiny, do ktorých boli priradené.
#
# Dataset obsahuje príznaky:
#  - `team` - názov tímu
#  - `group` - skupina, v ktorej tím bude hrať
#
# https://www.kaggle.com/datasets/amineteffal/qatar2022worldcupschudule?select=Qatar2022-teams.csv

# %%
results.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
#latest FIFA rankings
ranking['rank_date'].tail(1)
# Out:
# 64126    2022-12-22
# Name: rank_date, dtype: object

# %%
#change dates to pd.datetime
results['date'] = pd.to_datetime(results['date'])
ranking['rank_date'] = pd.to_datetime(ranking['rank_date'])

# %% [markdown]
# Staré zápasy už dnes nie sú relevantné, preto sa obmedzíme na zápasy od roku 2018, kedy sa odohrávali posledné majstrovstvá sveta.

# %%
results = results[(results['date'] >= '2018-8-1')].reset_index(drop=True)
ranking = ranking[(ranking['rank_date'] >= '2018-8-1') & (ranking['rank_date'] <= '2022-12-1')].reset_index(drop=True)

# %% [markdown]
# Niektoré krajiny majú v záznamoch nejednotné názvy, takže sa ich zbavíme.

# %%
ranking['country_full'] = ranking['country_full'].str.replace('IR Iran', 'Iran').str.replace('Korea Republic', 'South Korea')
results['home_team'] = results['home_team'].str.replace('United States', 'USA')
results['away_team'] = results['away_team'].str.replace('United States', 'USA')

# %% [markdown]
# 10 turnajov, na ktorých bolo odohraných najviac zápasov.

# %%
tournaments = results.groupby('tournament').size().reset_index(name='count')

#sort the data by the count in descending order
tournaments = tournaments.sort_values('count', ascending=False)

#select the top 10 values
top_10_tournaments = tournaments.head(10).sort_values('count',ascending=True)

#talking about football so everything will be green
cmap = cm.get_cmap('Greens')

#create a horizontal bar chart
#take log of counts so the lower count tournament arent so faded
plt.barh(top_10_tournaments['tournament'], top_10_tournaments['count'],
            color=cmap(np.log(top_10_tournaments['count']) / np.log(top_10_tournaments['count'].max())))
plt.ylabel('Tournament')
plt.xlabel('Count')
plt.title('Top 10 Tournaments')

# show the chart
plt.show()

# %% [markdown]
# Medzinárodné turnaje sa nehrajú často, takže najviac hier je odohraných ako priateľský zápas.

# %% [markdown]
# #### Najúspešnejšie tímy (strieľanie gólov)

# %%
home = results[['home_team', 'home_score']].rename(columns={'home_team':'team', 'home_score':'score'})
away = results[['away_team', 'away_score']].rename(columns={'away_team':'team', 'away_score':'score'})
teams = pd.concat([home, away])

teams_info = teams.groupby('team').agg({'score': ['sum'], 'team': ['size']})
teams_info.columns = ['goals_scored', 'num_matches']

#only take teams with above 5 games to avoid bias
teams_info = teams_info[teams_info['num_matches'] > 5]

teams_info['average'] = teams_info['goals_scored']/teams_info['num_matches']

# %%
#average goals scored
highest_average = teams_info.sort_values(by='average', ascending=False).head(10)
highest_average.plot(kind='bar', y='average', 
                    color=cmap(highest_average['average']/highest_average['average'].max()),
                    legend=False)
plt.title('Top 10 countries with the highest average goals per game ratio')
plt.xlabel('Country')
plt.ylabel('Average goals per game')
plt.show()

# %%
#total goals scored
highest_scored = teams_info.sort_values(by='goals_scored', ascending=False).head(10)
highest_scored.plot(kind='bar', y='goals_scored',
                    color=cmap(highest_scored['goals_scored']/highest_scored['goals_scored'].max()),
                    legend=False)
plt.title('Top 10 countries with most goals scored')
plt.xlabel('Country')
plt.ylabel('Total number of goals')
plt.show()

# %% [markdown]
# Datasetu results pridáme príznak `winner`, ktorý bude našou vysvetlovanou premennou, a hovorím o tom, či tím hrajúci ako domáci zvíťazil.

# %%
#take draw as a loss
results['winner'] = results.apply(lambda x : 1 if x['home_score'] > x['away_score'] else 0, axis=1)

# %%
total_matches_home = results.groupby('home_team').size().reset_index(name='total_matches')
total_matches_away = results.groupby('away_team').size().reset_index(name='total_matches')

#create new column for win_count
winner_home = pd.DataFrame(results.groupby('home_team').size() - results[results['winner'] == 0].groupby('home_team').size())
winner_away = pd.DataFrame(results[results['winner'] == 0].groupby('away_team').size())

#merge column into dataframe
total_matches_home = total_matches_home.merge(winner_home.reset_index(),left_on='home_team',right_on='home_team')
total_matches_away = total_matches_away.merge(winner_away.reset_index(),left_on='away_team',right_on='away_team')

total_matches_home.rename(columns={0: 'win_count'}, inplace=True)
total_matches_away.rename(columns={0: 'win_count'}, inplace=True)

# %% [markdown]
# #### Najúspešnejšie tímy (vyhraté zápasy)
# Tu tímy rozdelíme podľa toho, koľko zápasov vyhrávali v domácom a vo vonkajšom prostredí.
# Budeme pri tom sledovať tímy, ktoré vyhrali najviac zápasov, a tímy, ktoré vyhrali s najvyšším % vyhratých zápasov.

# %%
#top 10 teams by wins
win_top_10_home = total_matches_home.sort_values(by='win_count',ascending=False).head(10)

win_top_10_home.plot(x='home_team',y='win_count',kind='bar', 
                    color =cmap(win_top_10_home['win_count']/win_top_10_home['win_count'].max()))
plt.title('Top 10 Countries with most wins at home')
plt.xlabel('Country')
plt.ylabel('Number of wins')
plt.show()

# %%
#calculate win percentage
total_matches_home['win_percentage'] = total_matches_home['win_count'] / total_matches_home['total_matches'] * 100

#sort by win percentage and select top 10
percent_top_10_home = total_matches_home.sort_values(by='win_percentage',ascending=False).head(10)

#visualize using bar chart
percent_top_10_home.plot(x='home_team',y='win_percentage',kind='bar', 
                    color =cmap(percent_top_10_home['win_percentage']/percent_top_10_home['win_percentage'].max()))
plt.title('Top 10 Countries with highest win percentage at home')
plt.xlabel('Country')
plt.ylabel('Win Percentage')
plt.show()

# %%
#top 10 teams by wins
win_top_10_away = total_matches_away.sort_values(by='win_count',ascending=False).head(10)

win_top_10_away.plot(x='away_team',y='win_count',kind='bar', 
                    color =cmap(win_top_10_away['win_count']/win_top_10_away['win_count'].max()))
plt.title('Top 10 Countries with most wins away')
plt.xlabel('Country')
plt.ylabel('Number of wins')
plt.show()

# %%
#avoid bias by countries with just 1 away game
total_matches_away = total_matches_away[total_matches_away['win_count'] > 5]

#calculate win percentage
total_matches_away['win_percentage'] = total_matches_away['win_count'] / total_matches_away['total_matches'] * 100

#sort by win percentage and select top 10
percent_top_10_away = total_matches_away.sort_values(by='win_percentage',ascending=False).head(10)

#visualize using bar chart
percent_top_10_away.plot(x='away_team',y='win_percentage',kind='bar', 
                    color =cmap(percent_top_10_away['win_percentage']/percent_top_10_away['win_percentage'].max()))
plt.title('Top 10 Countries with highest win percentage away')
plt.xlabel('Country')
plt.ylabel('Win Percentage')
plt.show()

# %% [markdown]
# Ani jedna krajina sa nenachádza v top 10 pri zápasoch v domácom aj vonkajšom prostredí naraz, takže z toho je vidieť, že na prostredí, v ktorom sa zápas bude hrať záleží.

# %% [markdown]
# #### Evolúcia terajších 10 najlepších tímov od roku 2018

# %%
#most recent ranking
last_timestamp = ranking['rank_date'].max()

#list of latest top 10 teams
curr_top_10 = ranking[(ranking['rank'] <= 10) & (ranking['rank_date'] == last_timestamp)]['country_full'].unique()
#put into dataframe
curr_top_10 = ranking[ranking['country_full'].isin(curr_top_10)]

#most recent order of the countries
order = curr_top_10[curr_top_10['rank_date'] == last_timestamp].sort_values(by='rank')
order = order['country_full'].values.tolist()

#pivot the dataframe
curr_top_10 = curr_top_10.pivot(values='rank', index='rank_date', columns='country_full')

ax = curr_top_10.plot(kind='line')
plt.yticks(range(1, 23, 2))
plt.xticks(['2019-01-01', '2020-01-01', '2021-01-01', '2022-01-01'])
#1 needs to be on top
plt.gca().invert_yaxis()

handles, labels = ax.get_legend_handles_labels()

# Sort the labels and handles based on recent order
sorted_handles = [handle for _,handle in sorted(zip(labels, handles), key=lambda x: order.index(x[0]))]
sorted_labels = sorted(labels, key=lambda x: order.index(x))

plt.legend(sorted_handles, sorted_labels, loc='center left', bbox_to_anchor=(1, 3/4))
plt.title('Evolution of current top 10 ranked teams sice 2018.')
plt.xlabel('date')
plt.ylabel('rank')
plt.show()

# %% [markdown]
# # Úprava dát
# Nejaké menšie úpravy sme na dátach už previedli pri prezentovaní dát, teraz však potrebujeme dostať dáta do podoby, kde ich budeme môcť použiť na trénovanie násho modelu.

# %% [markdown]
# V žiadnom z naších datasetoch sa nenachádzajú chýbajúce dáta, takže ich nemusíme dopĺňať.

# %%
for dataset in [results, ranking, schedule, wc_teams]:
    #first sum gives columns, second number of nan in whole dataset
    print(dataset.isna().sum().sum())
# Out:
# 0
# 0
# 0
# 0

# %%
#drop redundant columns
results.drop(['city','country'], inplace=True, axis=1)

# %% [markdown]
# Dátumy v datasetoch results a ranking sú rôzne, takže nahradíme dátumy v datasete results najbližsím dátumom danej krajiny z datasetu ranking. To nám veľmi zjednoduší ďalšiu prácu s dátami.

# %%
def closest_date(date, country):
    """finds closest date from dataset ranking"""

    #only search for date where current country was ranked
    country_ranks = ranking[ranking['country_full'] == country]

    #if country is not in ranks return original date
    if not country_ranks.shape[0]:
        return date

    index = (country_ranks['rank_date'] - date).abs().idxmin()
    return country_ranks.loc[index]['rank_date']


results['home_rank_date'] = results.apply(lambda x: closest_date(x['date'], x['home_team']), axis=1)
results['away_rank_date'] = results.apply(lambda x: closest_date(x['date'], x['away_team']), axis=1)

# %% [markdown]
# Spojenie datasetov results a ranking do jedného.

# %%
#merge rankings for home teams
df=results.merge(ranking[['country_full', 'total_points', 'rank', 'rank_date']],
                        left_on=['home_rank_date', 'home_team'],
                        right_on=['rank_date', 'country_full']).drop(['rank_date', 'country_full'], axis=1)

#rename columns to not mix them up
df = df.rename(columns={'total_points': 'home_total_points', 'rank': 'home_rank'})


#merge rankings for away teams
df=df.merge(ranking[['country_full', 'total_points', 'rank', 'rank_date']],
                        left_on=['away_rank_date', 'away_team'],
                        right_on=['rank_date', 'country_full']).drop(['rank_date', 'country_full'], axis=1)

df = df.rename(columns={'total_points': 'away_total_points', 'rank': 'away_rank'})

#hove a column date for both home and away
df.drop(['home_rank_date','away_rank_date'],axis=1 , inplace = True)

# %% [markdown]
# ### Feature engineering
# Dátam pridáme nové príznaky vytvorené z tých pôvodných. Tieto príznaky nám výrazne pomôžu pri trénovaní nášho modelu.

# %%
#difference in ranks of the countries plazing the match
df['rank_dif'] = df['home_rank'] - df['away_rank']
#difference in FIFA points
df['point_dif'] = df['home_total_points'] - df['away_total_points']
df['rank_avg'] = (df['home_rank'] + df['away_rank']) / 2
#1 if match was important (wasnt just a friendly game)
df['is_important'] = df.apply(lambda x : True if x['tournament'] != 'Friendly' else False, axis=1)
df['is_worldcup'] = df.apply(lambda x : True if x['tournament'] == 'FIFA World Cup' else False, axis=1)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(17, 13)

#pick just the features that will be used in the model
corr = df[['winner', 'rank_dif', 'point_dif', 'rank_avg', 'is_important', 'is_worldcup', 'neutral']].corr()


sns.heatmap(corr,annot=True)
plt.title('Correlation heatmap of dataset features')
plt.show()

# %% [markdown]
# Z mapy korelácie príznakov sa dá predpokladať, že víťaz zápasu bude najviac záležať na príznakoch `point_dif` a `rank_dif` a naopak príznaky `is_important` a `is_world_cup` majú nízku koreláciu s vysvetlovanou premennou, takže ich pri trénovaní modelu nepoužijeme. Príznak `rank_avg` má takisto nízku koreláciu s `winner`, ale ako uvidíme neskôr tento príznak niektoré modely využívajú.

# %%
df = df[['winner', 'home_team','away_team', 'rank_dif', 'point_dif', 'rank_avg', 'neutral']]

# %% [markdown]
# # Trénovanie modelov

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import ParameterGrid
from sklearn.metrics import roc_curve,plot_confusion_matrix
from sklearn.inspection import permutation_importance
from sklearn.metrics import roc_auc_score
import sklearn.metrics as metrics

# %% [markdown]
# Rozdelíme dáta na trénovaciu a validačnú množinu. Našou vysvetľovanou premennou bude `winner`.

# %%
rd_seed = 42
#drop columns with strings
X_train, X_val, y_train, y_val = train_test_split(df.drop(columns=['winner','home_team','away_team']), 
                                                    df['winner'], 
                                                    test_size=0.25, 
                                                    random_state=rd_seed)

# %% [markdown]
# Pre každý model sa pokúsime nájsť čo najlepšiu kombináciu **hyperparametrov**.

# %%
def hyperparameter_tuning(param, Model):
    """function that finds the best combination of hyperparameters for a given model"""

    #create all combinations of given hyperparameters
    param_grid = ParameterGrid(param)

    val_acc = []

    for params in param_grid:
        model = Model(**params)
        model.fit(X_train, y_train)

        #store accuracy using current hyperparameters
        val_acc.append(metrics.accuracy_score(y_val, model.predict(X_val)))
    
    #return the combination with highest accuracy
    return param_grid[np.argmax(val_acc)]

# %% [markdown]
# Pre každý model taktiež zobrazíme **roc krivku** a **maticu zámen**.

# %%
def plot_roc_curve(probs):
    """function that draws a roc curve for a given model"""

    fpr, tpr, _ = roc_curve(y_val, probs)

    #visualize the curve
    plt.plot(fpr, tpr, label='ROC', color='limegreen')
    plt.plot([0, 1], [0, 1], linestyle='--', color='darkgreen')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend()
    plt.show()

# %%
def importance_bar(model):
    """function that draws a bar plot of importance of each feature for a given model"""

    #compute permutation importance
    result = permutation_importance(model, X_val, y_val, n_repeats=10, random_state=0)
    importance = result.importances_mean

    #visualize the feature importance
    plt.bar(X_train.columns, importance, color='green')
    plt.title('Importance of each feature in model')
    plt.xlabel('Feature name')
    plt.ylabel('Permutation importance')
    plt.show()

# %%
def test_model(model):
    """puts other functions together and also returns accuracy of the model"""

    model.fit(X_train, y_train)
    probs = model.predict_proba(X_val)[:, 1]
    auc = metrics.roc_auc_score(y_val, probs)
    print('Accuracy score for train data: {0:.5f}'.format(metrics.accuracy_score(y_train, model.predict(X_train))))
    print('Accuracy score for validation data: {0:.5f}'.format(metrics.accuracy_score(y_val, model.predict(X_val))))
    print('AUC score for validation data: {0:.5f}'.format(auc))
    #call all other functions
    
    plot_roc_curve(probs)
    plot_confusion_matrix(model, X_val, y_val, cmap=plt.cm.Greens, normalize = 'all')
    plt.title("Confusion Matrix")
    plt.show()
    importance_bar(model)

    return (metrics.accuracy_score(y_train, model.predict(X_train)), metrics.accuracy_score(y_val, model.predict(X_val)),auc)

# %% [markdown]
# ### Decision Tree

# %%
param_dt = {
    'max_depth': range(1, 30), 
    'criterion': ['entropy', 'gini', 'log_loss']}

best_params_dt = hyperparameter_tuning(param_dt, DecisionTreeClassifier)
print(best_params_dt)
# Out:
# {'max_depth': 4, 'criterion': 'entropy'}

# %%
dt = DecisionTreeClassifier(**best_params_dt)
dt_train, dt_val, dt_auc = test_model(dt)
# Out:
# Accuracy score for train data: 0.72782
# Accuracy score for validation data: 0.71606
# AUC score for validation data: 0.78877

# %% [markdown]
# ### K-nearest neighbours

# %%
param_kNN = {
    'n_neighbors' : range(1,10),
    'p' : range(1,5),
    'weights': ['uniform', 'distance']}

best_params_kNN = hyperparameter_tuning(param_kNN, KNeighborsClassifier)
print(best_params_kNN)
# Out:
# {'weights': 'uniform', 'p': 1, 'n_neighbors': 9}

# %%
kNN = KNeighborsClassifier(**best_params_kNN)
kNN_train, kNN_val, kNN_auc = test_model(kNN)
# Out:
# Accuracy score for train data: 0.75500
# Accuracy score for validation data: 0.71154
# AUC score for validation data: 0.76981

# %% [markdown]
# ### Random Forest

# %%
param_rf = {
    'n_estimators':[1,2,3,4,5,6,7,9,10,16,32],
    'max_depth': range(1,10)}

best_params_rf = hyperparameter_tuning(param_rf, RandomForestClassifier)
print(best_params_rf)
# Out:
# {'n_estimators': 16, 'max_depth': 5}

# %%
rf = RandomForestClassifier(**best_params_rf)
rf_train, rf_val, rf_auc = test_model(rf)
# Out:
# Accuracy score for train data: 0.74556
# Accuracy score for validation data: 0.72285
# AUC score for validation data: 0.80142

# %% [markdown]
# ### Logistic Regression

# %%
param_lr = {
    'penalty' : ['l2', 'none'],
    'max_iter' : [100, 200, 400, 500, 700, 1000, 2000, 3000],
    'solver' : ['lbfgs',  'newton-cg', 'sag', 'saga']}

best_params_lr = hyperparameter_tuning(param_lr, LogisticRegression)
print(best_params_lr)
# Out:
# {'solver': 'lbfgs', 'penalty': 'none', 'max_iter': 100}

# %%
lr = LogisticRegression(**best_params_lr)
lr_train, lr_val, lr_auc = test_model(lr)
# Out:
# Accuracy score for train data: 0.72216
# Accuracy score for validation data: 0.72964
# AUC score for validation data: 0.79712

# %%
#dataframe of all models
models = pd.DataFrame({
    'model': ['Decision Tree', 'KNN', 'Random Forest', 'Logistic Regression'],
    'train_acc' : [dt_train, kNN_train, rf_train, lr_train],
    'val_acc' : [dt_val, kNN_val, rf_val, lr_val],
    'auc_score' : [dt_auc, kNN_auc, rf_auc, lr_auc]})

models['train_acc'] = round(models['train_acc'], 5)
models['val_acc'] = round(models['val_acc'], 5)
models['auc_score'] = round(models['auc_score'], 5)
models.set_index('model', inplace=True)

# %%
sns.barplot(x=models.index, y=models["train_acc"], color="darkgreen", label="Train_Acc")
sns.barplot(x=models.index, y=models["val_acc"], color="forestgreen", label="Val_Acc")
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
models.sort_values(by='val_acc', ascending=False).head()
# Out:
#                      train_acc  val_acc  auc_score
# model
# Logistic Regression    0.72216  0.72964    0.79712
# Random Forest          0.74556  0.72285    0.80142
# Decision Tree          0.72782  0.71606    0.78877
# KNN                    0.75500  0.71154    0.76981

# %% [markdown]
# Na predikovanie zápasov majstrovstiev sveta vyberieme **logistickú regresiu**, pretože mala najvyššiu presnosť na validačných dátach a taktiež mala najvyššie auc skóre.

# %% [markdown]
# # Majstrovstvá sveta v Qatare 2022

# %%
#keep only the teams participating in the world cup
wc_teams_ranking = ranking.loc[(ranking['rank_date'] == ranking['rank_date'].max()) & (ranking['country_full'].isin(wc_teams['Team'].unique()))].copy()
wc_teams_ranking.set_index('country_full', inplace=True)

# %% [markdown]
# Keďže majstrovstvá sveta sa hrajú v Qatare (na neutrálnej pôde) nechceme aby tím hrajúci ako "domáci" mal výhodu tak ako pravdepodobnosť výhry budeme brať priemer pravdepodobností, že vyhrá tím1 keď je označený ako domáci a že vyhrá tím1 keď je tím2 označený ako domáci.

# %%
def predict_match(country1, country2):
    """calculates the chance of country1 winning the match"""

    point_dif = wc_teams_ranking.loc[country1, 'total_points'] - wc_teams_ranking.loc[country2, 'total_points']
    rank_dif = wc_teams_ranking.loc[country1, 'rank'] - wc_teams_ranking.loc[country2, 'rank']
    rank_avg = (wc_teams_ranking.loc[country1, 'rank'] + wc_teams_ranking.loc[country2, 'rank']) / 2

    #create 1 row dataframes for the model
    #all matches are in world cup and important and on neutral field
    country1_home = pd.DataFrame({'rank_dif' : rank_dif, 'point_dif' : point_dif , 'rank_avg' : rank_avg, 'neutral' : 1}, index=[0])
    country2_home = pd.DataFrame({ 'rank_dif' : -rank_dif, 'point_dif' : -point_dif ,'rank_avg' : rank_avg, 'neutral' : 1}, index=[0])

    #predict the outcomes
    country1_home_prob = lr.predict_proba(country1_home)
    country2_home_prob = lr.predict_proba(country2_home)

    #return the average win percentage
    return (country1_home_prob[0][1] + country2_home_prob[0][0]) / 2

# %% [markdown]
# ### Predpovedanie skupinovej fázy šampionátu

# %%
#create a win probability column for the schedule dataset
schedule['win_prob'] = 0

for index,row in schedule.iloc[:48].iterrows():
    #add win probabilty for each match
    schedule.loc[index, 'win_prob'] = predict_match(row['country1'], row['country2'])

# %%
#create a dataframe of group stage
group_stage = schedule.merge(wc_teams[['Group','Team']], left_on='country1', right_on='Team')
group_stage.drop('Team', axis=1, inplace=True)

# %%
for group_letter in sorted(group_stage['Group'].unique()):
    #matches in current group
    group_matches = group_stage[group_stage['Group'] == group_letter]

    print(f'-------Group {group_letter}-------')

    for index, row in group_matches.iterrows():
        if row['win_prob'] > 0.55:
            #country1 won
            print(f'{row["country1"]} vs {row["country2"]} : {row["country1"]} wins with probability of {round(row["win_prob"], 2)}')
        elif row['win_prob'] < 0.45:
            #country2 won
            print(f'{row["country1"]} vs {row["country2"]} : {row["country2"]} wins with probability of {round(1-row["win_prob"], 2)}')
        else:
            print(f'{row["country1"]} vs {row["country2"]} : Draw')
# Out:
# -------Group A-------
# Qatar vs Ecuador : Draw
# Qatar vs Senegal : Senegal wins with probability of 0.69
# Senegal vs Netherlands : Netherlands wins with probability of 0.65
# Netherlands vs Ecuador : Netherlands wins with probability of 0.78
# Netherlands vs Qatar : Netherlands wins with probability of 0.81
# Ecuador vs Senegal : Senegal wins with probability of 0.66
# -------Group B-------
# England vs Iran : England wins with probability of 0.72
# England vs USA : England wins with probability of 0.64
# USA vs Wales : USA wins with probability of 0.58
# Wales vs Iran : Draw
# Wales vs England : England wins with probability of 0.71
# Iran vs USA : USA wins with probability of 0.59
# -------Group C-------
# Mexico vs Poland : Mexico wins with probability of 0.63
# Argentina vs Saudi Arabia : Argentina wins with probability of 0.87
# Argentina vs Mexico : Argentina wins with probability of 0.67
# Poland vs Saudi Arabia : Poland wins with probability of 0.64
# ...

# %%
#create column for points gained by a team
wc_teams_ranking['points_gained'] = 0

for index,match in group_stage.iterrows():
    #countries get 3 points for a win and 1 point for a draw
    if match['win_prob'] > 0.55:
        wc_teams_ranking.loc[match['country1'],'points_gained'] += 3
    elif match['win_prob'] < 0.45:
        wc_teams_ranking.loc[match['country2'],'points_gained'] += 3
    else:
        wc_teams_ranking.loc[match['country1'],'points_gained'] += 1
        wc_teams_ranking.loc[match['country2'],'points_gained'] += 1

# %%
#create a knockout stage dataframe
knockout_stage = schedule.iloc[48:].copy()
knockout_stage.reset_index(drop=True,inplace=True)

# %%
def compare_points(country1, country2):
    """compares place of two countries in their group"""

    if wc_teams_ranking.loc[country1, 'points_gained'] > wc_teams_ranking.loc[country2, 'points_gained']:
        return -1
    elif wc_teams_ranking.loc[country1, 'points_gained'] < wc_teams_ranking.loc[country2, 'points_gained']:
        return 1
    else:
        #secondary sorting if countries have the same amount of points
        match_prediction = predict_match(country1, country2)
        if match_prediction >= 0.5:
            return -1
        else:
            return 1

# %%
def insert_group_winner(place, team):
    """inserts a country into the knockout stage dataframe"""

    #check which column the country belongs to
    if knockout_stage.loc[knockout_stage['country1'] == place].shape[0]:
        knockout_stage.loc[knockout_stage['country1'] == place, 'country1'] = team
    else:
        knockout_stage.loc[knockout_stage['country2'] == place, 'country2'] = team

# %% [markdown]
# Z každej skupiny postupujú prvé dve mužstvá do vyraďovacej fázy turnaja.

# %%
from functools import cmp_to_key

for group_letter in sorted(group_stage.Group.unique()):

    #current group
    group_matches = group_stage[group_stage['Group'] == group_letter]
    #all teams in the group
    group_teams = pd.concat([group_matches['country1'], group_matches['country2']]).unique()
    
    #sort teams by thier points
    group_teams = sorted(group_teams, key=cmp_to_key(compare_points))

    #first place
    insert_group_winner('1' + group_letter.upper(), group_teams[0])
    #second place
    insert_group_winner('2' + group_letter.upper(), group_teams[1])

    print(f'-------Group {group_letter}-------')
    for team in group_teams:
        print(team,':', wc_teams_ranking.loc[team, 'points_gained'], 'points')
# Out:
# -------Group A-------
# Netherlands : 9 points
# Senegal : 6 points
# Ecuador : 1 points
# Qatar : 1 points
# -------Group B-------
# England : 9 points
# USA : 6 points
# Wales : 1 points
# Iran : 1 points
# -------Group C-------
# Argentina : 9 points
# Mexico : 6 points
# Poland : 3 points
# Saudi Arabia : 0 points
# -------Group D-------
# France : 9 points
# Denmark : 6 points
# Tunisia : 1 points
# Australia : 1 points
# -------Group E-------
# Spain : 9 points
# Germany : 6 points
# Japan : 3 points
# Costa Rica : 0 points
# -------Group F-------
# Belgium : 9 points
# Croatia : 6 points
# Morocco : 3 points
# Canada : 0 points
# -------Group G-------
# Brazil : 9 points
# Switzerland : 6 points
# Serbia : 3 points
# Cameroon : 0 points
# -------Group H-------
# Portugal : 9 points
# Uruguay : 6 points
# South Korea : 3 points
# Ghana : 0 points

# %% [markdown]
# Do vyraďovacej fázy turnaja postupuje teda 16 tímov, z toho 10 tímov, ktoré postúpili podľa nášho modelu, postúpili aj v skutočnosti.

# %% [markdown]
# ### Predpovedanie vyraďovacej fázy šampionátu

# %%
def add_win_prob(fr,to):
    """adds win probability to the knockout_stage dataframe"""

    for index,row in knockout_stage.iloc[fr:to].iterrows():
        knockout_stage.loc[index, 'win_prob'] = round(predict_match(row['country1'], row['country2']), 2)

# %%
def print_results(fr,to,name):
    """prints results of current stage"""

    print(f'-------{name}-------')
    
    for index, row in knockout_stage.iloc[fr:to].iterrows():
        #dont take draws in the knockout stages
        if row['win_prob'] > 0.50:
            print(f'{row["country1"]} vs {row["country2"]} : {row["country1"]} wins with probability of {round(row["win_prob"], 2)}')
            insert_group_winner('W' + str(index+49), row['country1'])
            
            #losers play for 3rd place
            if name=="Semi Finals":
                insert_group_winner('L' + str(index + 49), row['country2'])
        else:
            print(f'{row["country1"]} vs {row["country2"]} : {row["country2"]} wins with probability of {round(1-row["win_prob"], 2)}')
            insert_group_winner('W' + str(index + 49), row['country2'])

            #3rd place
            if name=="Semi Finals":
                insert_group_winner('L' + str(index + 49), row['country1'])

# %%
add_win_prob(0,8)
print_results(0,8,'Round of 16')

add_win_prob(8,12)
print_results(8,12,'Quarter Finals') 

add_win_prob(12,14)
print_results(12,14,'Semi Finals')

add_win_prob(14,16)
print_results(14,15,'Third Place')

print_results(15,16,'Final')
# Out:
# -------Round of 16-------
# Netherlands vs USA : Netherlands wins with probability of 0.59
# Argentina vs Denmark : Argentina wins with probability of 0.65
# England vs Senegal : England wins with probability of 0.69
# France vs Mexico : France wins with probability of 0.65
# Spain vs Croatia : Spain wins with probability of 0.6
# Brazil vs Uruguay : Brazil wins with probability of 0.76
# Belgium vs Germany : Belgium wins with probability of 0.72
# Portugal vs Switzerland : Portugal wins with probability of 0.55
# -------Quarter Finals-------
# Netherlands vs Argentina : Argentina wins with probability of 0.61
# Spain vs Brazil : Brazil wins with probability of 0.67
# England vs France : France wins with probability of 0.54
# Belgium vs Portugal : Belgium wins with probability of 0.69
# -------Semi Finals-------
# Argentina vs Brazil : Brazil wins with probability of 0.59
# France vs Belgium : Belgium wins with probability of 0.58
# -------Third Place-------
# ...

# %% [markdown]
# Brazília turnaj nevyhrala, ale bola označovaná za najväčšieho favorita, takže model dosiahol predpokladaných výsledkov.

# %%
import networkx as nx
from networkx.drawing.nx_pydot import graphviz_layout
import pydot
import matplotlib.patches as mpatches

# %%
#list of labels for knockout stage graph
labels = []

for index,row in knockout_stage.iterrows():
    #third place is not in the ladder
    if row['phase']!='third place':
        
        #string for both countries and their win probability
        label = f"{row['country1']} ({round(row['win_prob'], 2)}) \n {row['country2']} ({round(1-row['win_prob'], 2)})"
        labels.append(label)

# %%
#balanced tree of depth 3 and every node branches into 2
G = nx.balanced_tree(2, 3)

# layout for the nodes
pos = graphviz_layout(G,prog='twopi')

# %%
#dictionary of labels for the graph
labels_dict = {}

for index, label in enumerate(list(reversed(labels))):
    #items in dictionary are index : label
    labels_dict[index] = label

# %%
#each index is a number 1 to 4 based on phase of the tournament
phases = [4 - int(np.log2(i)) for i in range(1, 16)]

#every phase has its own green color
colors = [(0, i/4, 0) for i in phases]

legend_colors = [(0, i/4, 0) for i in (4, 3, 2, 1)]
names = ['Final','Semi Finals','Quarter Finals','Round of 16']

# %%
#draw the graph
nx.draw(G, pos=pos, with_labels=False, node_size = 5000, node_color = colors, width=8)
nx.draw_networkx_labels(G, pos=pos, bbox=dict(boxstyle="round,pad=0.1", fc="white", ec="black", lw=.5), labels=labels_dict, font_size=12)

plt.title('Knockout stage')
patches = [mpatches.Patch(color=colors[i], label=names[i]) for i in range(4)]
plt.legend(handles=patches)
plt.show()

# %% [markdown]
# # Záver
# Skutočné finále sa odohrávalo medzi Francúzskom a Argentínou, a tieto tímy sa v našej simulácii dostali do semifinále a bojovali spolu o 3. miesto, čiže od pravdy sme príliš ďaleko neboli.
#
# V skutočnosti je ale predpovedanie výsledkov futbalových zápasov omnoho komplexnejšie. Predpovedať, že zápas vyhrá outsider je pre počítač veľmi náročné, pretože v takýchto zápasoch ide často o šťastie, alebo iné faktory, ku ktorým počítač nemá prístup.
#
# Takže v závere by som povedal, že tento náš model určite nie je na škodu, ale peniaze by som na tie zápasy nestavil.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=eef35159-ed59-4fff-9f8a-64d0ca93799e' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
